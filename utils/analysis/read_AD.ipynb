# %% [markdown]
# ## Notebook to plot Aitchison Distance versus Read Length

# %%
import pandas as pd
import re
import seaborn as sns
import matplotlib.pyplot as plt

# %%
reads_df = pd.read_csv('../paper/read_stats.csv', encoding='utf-8')
reads_df.set_index("Community", inplace=True)
reads_recode = {
    "sub_bmock12": "S1_bmock12",
    "amos_hilo": "hilo",
    "amos_mixed": "mixed",
    "S1_camisim": "S1_camisimGI",
    "S2_camisim": "S2_camisimGI",
    "Mix-A": "MIX-A",
    "Mix-B": "MIX-B",
    "Mix-C": "MIX-C",
    "Mix-D": "MIX-D",
}

reads_df = reads_df.rename(reads_recode)
display(reads_df)
# Out:
#                              num_seqs                       sum_len  \
# Community
# S1_bmock12       100500000.00 +- 0.00        15175500000.00 +- 0.00
# S1_camisimGI      16666158.00 +- 0.00  2473504212.50 +- 12668039.31
# S2_camisimGI      16666291.00 +- 0.00  2473723888.00 +- 12664634.59
# EG_nist            3353278.00 +- 0.00    282025983.00 +- 3833426.68
# Mix-A_nist         3473553.00 +- 0.00    365925482.50 +- 2529868.96
# Mix-B_nist         3583192.00 +- 0.00    376371686.50 +- 2769876.56
# Mix-C_nist         2974354.00 +- 0.00    325816856.00 +- 2268975.55
# Mix-D_nist         3278203.00 +- 0.00    373347674.50 +- 2103394.48
# tourlousse    5897627.83 +- 378678.85   855639825.08 +- 51884672.55
# hilo          1899005.80 +- 172132.60   380831440.00 +- 34742124.05
# mixed         2012091.00 +- 184747.85   403848279.20 +- 37416661.58
# hmp_gut       2901295.10 +- 356896.97   269739388.40 +- 34622935.73
#
#                      min_len         avg_len         max_len
# Community
# S1_bmock12    151.00 +- 0.00  151.00 +- 0.00  151.00 +- 0.00
# S1_camisimGI   31.00 +- 0.00  148.45 +- 0.78  150.00 +- 0.00
# S2_camisimGI   31.00 +- 0.00  148.45 +- 0.78  150.00 +- 0.00
# EG_nist        15.00 +- 0.00   84.10 +- 1.13  151.00 +- 0.00
# Mix-A_nist     19.00 +- 5.66  105.35 +- 0.78  151.00 +- 0.00
# Mix-B_nist     18.50 +- 4.95  105.05 +- 0.78  151.00 +- 0.00
# Mix-C_nist     16.50 +- 2.12  109.55 +- 0.78  151.00 +- 0.00
# Mix-D_nist     20.00 +- 7.07  113.85 +- 0.64  151.00 +- 0.00
# tourlousse     15.00 +- 0.00  145.12 +- 1.31  151.00 +- 0.00
# hilo          100.00 +- 0.00  200.54 +- 1.93  205.00 +- 0.00
# mixed         100.00 +- 0.00  200.71 +- 1.55  205.00 +- 0.00
# hmp_gut        15.00 +- 0.00   92.91 +- 1.01  101.00 +- 0.00

# %%
def make_joined(df_left: pd.DataFrame, df_right: pd.DataFrame):
    joined = pd.merge(df_left, df_right, how="left", left_on="combined_name", right_index=True)

    cols = joined.columns.to_list()[13:]

    for c in cols:
        joined = split_cols(joined, c, sep = "+-")

    return joined


def split_cols(df: pd.DataFrame, col: str, sep: str = ','):
    """Split a column into multiple columns"""
    df = df.copy()
    # display(df)
    df[[col, f'{col}_stddev']] = df[col].str.split(re.escape(sep), expand=True)
    # df = df.explode(col)
    # display(df)
    return df

# %%
combined_df = pd.DataFrame()

stats_df = pd.read_csv('all_stats_species.csv')
stats_df["combined_name"] = stats_df["SampleID"] + "_" + stats_df["Source"]
for t, t_df in stats_df.groupby("threshold"):
    for pl, pl_df in t_df.groupby("Pipeline"):
        for src, src_df in pl_df.groupby("Source"):
            # print(src)
            if src == "hilo" or src == "mixed" or src == "tourlousse":
                src_df.loc['mean'] = src_df.mean(numeric_only=True, axis=0)
                mean = src_df.loc[['mean']].copy()
                mean["Source"] = src
                mean["Pipeline"] = pl
                mean["combined_name"] = src
                # display(mean.head())
                joined = make_joined(mean, reads_df)
                
                combined_df = pd.concat([combined_df, joined])
            else:
                # display(src_df.head())
                joined = make_joined(src_df, reads_df)

                combined_df = pd.concat([combined_df, joined])
            
combined_df.to_csv("stats_reads_combined.csv", index=False)

# %%
# combined_df.to_csv("stats_reads_combined.csv", index=False)
combined_df["AD"] = combined_df["AD"].astype(float)
combined_df["avg_len"] = combined_df["avg_len"].astype(float)
combined_df["num_seqs"] = combined_df["num_seqs"].astype(float)
combined_df["sum_len"] = combined_df["sum_len"].astype(float)

# Make a scatterplot of AD vs avg_len
sns.set_theme(style="whitegrid")
sns.set_context("paper", font_scale=1.5)
sns.set_style("ticks")

# Use avg_len, num_seqs, sum_len
x_labels = ["avg_len", "num_seqs", "sum_len"]
for x in x_labels:
    g = sns.lmplot(data=combined_df, x=x, y="AD", hue="Pipeline", height=5, aspect=1.5, ci=None, fit_reg=True)
    plt.show()
