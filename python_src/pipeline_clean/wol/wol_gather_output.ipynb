# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import sys

sys.path.append("../../../utils")
from data_paths import *

# %%
def find_output_files(rank, data_dir):
    """Find output files from Woltka classify.
    
    Parameters
    ----------
    rank : str
        Taxonomic rank.
    data_dir : str
        Path to directory containing output files.
    
    Returns
    -------
    list
        List of paths to output files.
    """
    output_files = []
    for root, dirs, files in os.walk(data_dir):
        for file in files:
            if f"{rank}.tsv" == file:
                output_files.append(os.path.join(root, file))
    return output_files

# %%
def rel_abundance(df, output, rank, plot=False):
    # df.drop("FeatureID", axis=1, inplace=True)
    # pct = df[["Count"]].apply(lambda x: x / x.sum(), axis=0)
    df["RA"] = df["Count"] / df["Count"].sum()
    df.drop("Count", axis=1, inplace=True)
    df = df.sort_values(by="RA", ascending=False)

    # Remove any [ and ] from the index.
    df.index = df.index.str.replace("[", "", regex=False)
    df.index = df.index.str.replace("]", "", regex=False)

    # df = df.where(df > 5e-5).dropna()

    final_df = df[["RA", "TAX_ID"]]
    final_df.to_csv(output, sep=",")

    print("saved to: ", output)

    if plot:
        final_df.T.plot.bar(figsize=(10,10), xlabel="{rank} Name", ylabel="Fraction", title=f"{rank} Relative Abundance above 0.005%").legend(loc='center left', bbox_to_anchor=(1.0, 0.5), title=f"{rank}")
        plt.savefig(output + ".png", bbox_inches='tight')

# %%
# Find output files.
def find_and_save(input_data: str, rank: str, output_dir: str):
    """Find and save output files from Woltka classify.
    
    Parameters
    ----------
    input_data : str
        Path to directory containing output files.
    rank : str
        Taxonomic rank.
    output_dir : str
        Path to directory to save output files.
    """
    output_files = find_output_files(rank, input_data)
    for file in output_files:
        print(file)
        df = pd.read_csv(file, sep="\t", names=["TAX_ID", "Count", "Species"], header=0, index_col=2)

        sampleID = (os.path.dirname(file).split("/")[-1]).split("_")[0]
        output_path = os.path.join(output_dir, f"{sampleID.upper()}_{rank}_relabund_annotated.csv")
        rel_abundance(df, output_path, rank)

# %% [markdown]
# # Main

# %%
# data_dir = amos_hilo.woltka
# output_dir = os.path.abspath("../../pipelines/amos/hilo/wol/")
# if not os.path.exists(data_dir):
#     raise Exception("path does not exist.")

data_paths = make_data_list()
for d in data_paths:
    print(d.woltka)
    # if "bmock12" not in d.path:
        # continue

    output_dir = os.path.join(d.path, "wol")
    if not os.path.exists(output_dir):
        output_dir = os.path.join(d.path, "woltka")

    find_and_save(input_data=d.woltka, rank="genus", output_dir=output_dir)
    find_and_save(input_data=d.woltka, rank="species", output_dir=output_dir)
# Out:
# /Volumes/TBHD_share/valencia/pipelines/bmock12/woltka/classify/results
# /Volumes/TBHD_share/valencia/pipelines/bmock12/woltka/classify/results/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/bmock12/woltka/RESULTS_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/bmock12/woltka/classify/results/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/bmock12/woltka/RESULTS_species_relabund_annotated.csv
# /Volumes/TBHD_share/cami_data/NOADAPTERS/pipelines/woltka/classify
# /Volumes/TBHD_share/cami_data/NOADAPTERS/pipelines/woltka/classify/S2_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/camisimGI/woltka/S2_genus_relabund_annotated.csv
# /Volumes/TBHD_share/cami_data/NOADAPTERS/pipelines/woltka/classify/S1_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/camisimGI/woltka/S1_genus_relabund_annotated.csv
# /Volumes/TBHD_share/cami_data/NOADAPTERS/pipelines/woltka/classify/S2_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/camisimGI/woltka/S2_species_relabund_annotated.csv
# /Volumes/TBHD_share/cami_data/NOADAPTERS/pipelines/woltka/classify/S1_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/camisimGI/woltka/S1_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/microbio_spectrum/CLEANED/pipelines/woltka/classify
# /Volumes/TBHD_share/valencia/pipelines/microbio_spectrum/CLEANED/pipelines/woltka/classify/SRR17380242_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/tourlousse/woltka/SRR17380242_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/microbio_spectrum/CLEANED/pipelines/woltka/classify/SRR17380241_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/tourlousse/woltka/SRR17380241_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/microbio_spectrum/CLEANED/pipelines/woltka/classify/SRR17380246_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/tourlousse/woltka/SRR17380246_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/microbio_spectrum/CLEANED/pipelines/woltka/classify/SRR17380244_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/tourlousse/woltka/SRR17380244_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/microbio_spectrum/CLEANED/pipelines/woltka/classify/SRR17380243_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/tourlousse/woltka/SRR17380243_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/microbio_spectrum/CLEANED/pipelines/woltka/classify/SRR17380245_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/tourlousse/woltka/SRR17380245_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/microbio_spectrum/CLEANED/pipelines/woltka/classify/SRR17380242_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/tourlousse/woltka/SRR17380242_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/microbio_spectrum/CLEANED/pipelines/woltka/classify/SRR17380241_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/tourlousse/woltka/SRR17380241_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/microbio_spectrum/CLEANED/pipelines/woltka/classify/SRR17380246_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/tourlousse/woltka/SRR17380246_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/microbio_spectrum/CLEANED/pipelines/woltka/classify/SRR17380244_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/tourlousse/woltka/SRR17380244_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/microbio_spectrum/CLEANED/pipelines/woltka/classify/SRR17380243_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/tourlousse/woltka/SRR17380243_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/microbio_spectrum/CLEANED/pipelines/woltka/classify/SRR17380245_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/tourlousse/woltka/SRR17380245_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/amos/nibsc/mixed/wol/classify
# /Volumes/TBHD_share/valencia/pipelines/amos/nibsc/mixed/wol/classify/SRR11487941_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/amos/mixed/woltka/SRR11487941_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/amos/nibsc/mixed/wol/classify/SRR11487939_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/amos/mixed/woltka/SRR11487939_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/amos/nibsc/mixed/wol/classify/SRR11487937_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/amos/mixed/woltka/SRR11487937_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/amos/nibsc/mixed/wol/classify/SRR11487940_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/amos/mixed/woltka/SRR11487940_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/amos/nibsc/mixed/wol/classify/SRR11487938_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/amos/mixed/woltka/SRR11487938_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/amos/nibsc/mixed/wol/classify/SRR11487941_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/amos/mixed/woltka/SRR11487941_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/amos/nibsc/mixed/wol/classify/SRR11487939_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/amos/mixed/woltka/SRR11487939_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/amos/nibsc/mixed/wol/classify/SRR11487937_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/amos/mixed/woltka/SRR11487937_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/amos/nibsc/mixed/wol/classify/SRR11487940_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/amos/mixed/woltka/SRR11487940_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/amos/nibsc/mixed/wol/classify/SRR11487938_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/amos/mixed/woltka/SRR11487938_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/amos/nibsc/hilo/woltka/classify
# /Volumes/TBHD_share/valencia/pipelines/amos/nibsc/hilo/woltka/classify/SRR11487935_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/amos/hilo/woltka/SRR11487935_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/amos/nibsc/hilo/woltka/classify/SRR11487933_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/amos/hilo/woltka/SRR11487933_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/amos/nibsc/hilo/woltka/classify/SRR11487934_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/amos/hilo/woltka/SRR11487934_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/amos/nibsc/hilo/woltka/classify/SRR11487932_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/amos/hilo/woltka/SRR11487932_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/amos/nibsc/hilo/woltka/classify/SRR11487931_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/amos/hilo/woltka/SRR11487931_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/amos/nibsc/hilo/woltka/classify/SRR11487935_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/amos/hilo/woltka/SRR11487935_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/amos/nibsc/hilo/woltka/classify/SRR11487933_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/amos/hilo/woltka/SRR11487933_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/amos/nibsc/hilo/woltka/classify/SRR11487934_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/amos/hilo/woltka/SRR11487934_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/amos/nibsc/hilo/woltka/classify/SRR11487932_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/amos/hilo/woltka/SRR11487932_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/amos/nibsc/hilo/woltka/classify/SRR11487931_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/amos/hilo/woltka/SRR11487931_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/HMP/gut/wol/classify
# /Volumes/TBHD_share/valencia/pipelines/HMP/gut/wol/classify/SRR540392_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/hmp/gut/woltka/SRR540392_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/HMP/gut/wol/classify/SRR540389_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/hmp/gut/woltka/SRR540389_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/HMP/gut/wol/classify/SRR540693_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/hmp/gut/woltka/SRR540693_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/HMP/gut/wol/classify/SRR539860_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/hmp/gut/woltka/SRR539860_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/HMP/gut/wol/classify/SRR540399_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/hmp/gut/woltka/SRR540399_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/HMP/gut/wol/classify/SRR540381_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/hmp/gut/woltka/SRR540381_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/HMP/gut/wol/classify/SRR540371_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/hmp/gut/woltka/SRR540371_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/HMP/gut/wol/classify/SRR540397_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/hmp/gut/woltka/SRR540397_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/HMP/gut/wol/classify/SRR540637_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/hmp/gut/woltka/SRR540637_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/HMP/gut/wol/classify/SRR540385_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/hmp/gut/woltka/SRR540385_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/HMP/gut/wol/classify/SRR540392_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/hmp/gut/woltka/SRR540392_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/HMP/gut/wol/classify/SRR540389_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/hmp/gut/woltka/SRR540389_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/HMP/gut/wol/classify/SRR540693_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/hmp/gut/woltka/SRR540693_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/HMP/gut/wol/classify/SRR539860_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/hmp/gut/woltka/SRR539860_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/HMP/gut/wol/classify/SRR540399_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/hmp/gut/woltka/SRR540399_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/HMP/gut/wol/classify/SRR540381_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/hmp/gut/woltka/SRR540381_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/HMP/gut/wol/classify/SRR540371_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/hmp/gut/woltka/SRR540371_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/HMP/gut/wol/classify/SRR540397_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/hmp/gut/woltka/SRR540397_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/HMP/gut/wol/classify/SRR540637_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/hmp/gut/woltka/SRR540637_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/HMP/gut/wol/classify/SRR540385_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/hmp/gut/woltka/SRR540385_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/NIST/pipelines/woltka/classify
# /Volumes/TBHD_share/valencia/pipelines/NIST/pipelines/woltka/classify/EG_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/nist/woltka/EG_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/NIST/pipelines/woltka/classify/Mix-B_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/nist/woltka/MIX-B_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/NIST/pipelines/woltka/classify/Neg_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/nist/woltka/NEG_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/NIST/pipelines/woltka/classify/Mix-D_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/nist/woltka/MIX-D_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/NIST/pipelines/woltka/classify/Mix-C_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/nist/woltka/MIX-C_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/NIST/pipelines/woltka/classify/Mix-A_classify/genus.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/nist/woltka/MIX-A_genus_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/NIST/pipelines/woltka/classify/EG_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/nist/woltka/EG_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/NIST/pipelines/woltka/classify/Mix-B_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/nist/woltka/MIX-B_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/NIST/pipelines/woltka/classify/Neg_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/nist/woltka/NEG_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/NIST/pipelines/woltka/classify/Mix-D_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/nist/woltka/MIX-D_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/NIST/pipelines/woltka/classify/Mix-C_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/nist/woltka/MIX-C_species_relabund_annotated.csv
# /Volumes/TBHD_share/valencia/pipelines/NIST/pipelines/woltka/classify/Mix-A_classify/species.tsv
# saved to:  /Users/valenciaem/coding/pipelines/pipelines/nist/woltka/MIX-A_species_relabund_annotated.csv
